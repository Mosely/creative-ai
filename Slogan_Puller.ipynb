# %% [markdown]
# # Webscraping for Slogans

# %% [markdown]
# To acquire a dataset, we will need to scrape certain webpages which list out slogans for different companies. For this we will be using **beautifulsoup**.

# %%
from bs4 import BeautifulSoup
import urllib.request

# %% [markdown]
# Targeting our desired webpage and saving it for scraping:

# %%
# The URL
slogan_page = 'https://www.thebalancecareers.com/best-advertising-taglines-ever-39208'

# %%
# query the website and return the html to the variable ‘page’
page = urllib.request.urlopen(slogan_page)

# %% [markdown]
# Now we create the **beautifulsoup** variables for parsing:

# %%
# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page, 'html.parser')

# %% [markdown]
# Lets see it working:

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="comp flexTemplate html mntl-layout-html taxlevel-3 theme-1" data-ab="99,41,99,99,78,99,55" data-mantle-resource-version="3.9.23" data-money-careers-resource-version="3.10.0" data-money-resource-version="3.10.0" data-resource-version="3.10.0" id="flexTemplate_1-0" lang="en">
#  <!--
# <globe-environment environment="prod" application="money-careers" dataCenter="us-east-1"/>
# -->
#  <head class="loc head">
#   <script type="text/javascript">
#   </script>
#   <link href="//adservice.google.com" rel="preconnect"/>
#   <link href="//securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="//stats.g.doubleclick.net" rel="preconnect"/>
#   <link href="//js-sec.indexww.com" rel="preconnect"/>
#   <link href="//bcp.crwdcntrl.net" rel="preconnect"/>
#   <link href="//ad.crwdcntrl.net" rel="preconnect"/>
#   <link href="//c.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//cdn.adsafeprotected.com" rel="preconnect"/>
#   <link href="//as-sec.casalemedia.com" rel="preconnect"/>
#   <link href="//aax.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//s.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//tpc.googlesyndication.com" rel="preconnect"/>
#   <link href="//pagead2.googlesyndication.com" rel="preconnect"/>
#   <link href="//tags.crwdcntrl.net" rel="dns-prefetch"/>
#   <link href="//sb.scorecardresearch.com" rel="dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="dns-prefetch"/>
#   <link href="//pixel.adsafeprotected.com" rel="dns-prefetch"/>
#   <link href="/static/3.10.0/icons/favicons/favicon.ico" rel="shortcut icon"/>
#   <link href="/static/3.10.0/icons/favicons/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="/static/3.10.0/icons/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="/static/3.10.0/icons/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="/static/3.10.0/icons/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="/static/3.10.0/icons/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <meta content="#F4F4F4" name="msapplication-TileColor"/>
#   <meta content="/static/3.10.0/icons/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="/static/3.10.0/icons/favicons/mstile-70x70.png" name="msapplication-square70x70logo"/>
#   <meta content="/static/3.10.0/icons/favicons/mstile-150x150.png" name="msapplication-square150x150logo"/>
#   <meta content="/static/3.10.0/icons/favicons/mstile-310x310.png" name="msapplication-square310x310logo"/>
#   <meta content="/static/3.10.0/icons/favicons/mstile-310x150.png" name="msapplication-wide310x150logo"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="NOODP, NOYDIR" name="robots">
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <link href="https://www.thebalancecareers.com/best-advertising-taglines-ever-39208" rel="canonical">
#     <title>
#      The 100 Best Advertising Taglines Ever
#     </title>
#     <meta content="Here is a list of the 100 best taglines from brands around the world; most are American brands, but you may spot a few from other countries in there." itemprop="description" name="description"/>
#     <meta content="moneycareers,advertising,go-to-work-on-an-egg,n.-w.-ayer-&amp;-son,mauritian-militant-movement,maxwell-house,think-small" name="sailthru.tags">
#      <!-- Pinterest Pins -->
#      <meta content="Take a Look at This List of the 100 Best Advertising Taglines Ever" itemprop="name">
#       <meta content="The Balance" property="article:section">
#        <!-- Facebook Open Graph Tags -->
#        <meta content="157552701605251" property="fb:app_id">
#         <meta content="article" property="og:type">
#          <meta content="The Balance Careers" property="og:site_name">
#           <meta content="https://www.thebalancecareers.com/best-advertising-taglines-ever-39208" property="og:url">
#            <meta content="Take a Look at This List of the 100 Best Advertising Taglines Ever" property="og:title">
#             <meta content="Here is a list of the 100 best taglines from brands around the world; most are American brands, but you may spot a few from other countries in there." property="og:description"/>
#             <meta content="https://www.thebalancecareers.com/thmb/BQFW1mBeVZjcH-vbSkaLuiyWJ1w=/1922x1560/filters:fill(auto,1)/GettyImages-200121272-002-5894d3485f9b5874ee1d84d0.jpg" property="og:image"/>
#             <meta content="https://www.facebook.com/thebalancecom" property="article:author"/>
#             <!-- Twitter Cards -->
#             <meta content="summary" name="twitter:card"/>
#             <meta content="@thebalance" name="twitter:site"/>
#             <meta content="Take a Look at This List of the 100 Best Advertising Taglines Ever" name="twitter:title"/>
#             <meta content="Here is a list of the 100 best taglines from brands around the world; most are American brands, but you may spot a few from other countries in there." name="twitter:description"/>
#             <meta content="https://www.thebalancecareers.com/thmb/BQFW1mBeVZjcH-vbSkaLuiyWJ1w=/1922x1560/filters:fill(auto,1)/GettyImages-200121272-002-5894d3485f9b5874ee1d84d0.jpg" name="twitter:image"/>
#             <meta content="balcar_advertising-glossary" name="lotame:tax3"/>
#             <meta content="balcar_advertising" name="lotame:tax2"/>
#             <meta content="balcar_career-paths" name="lotame:tax1"/>
#             <meta content="bal" name="lotame:tax0"/>
#             <script type="application/ld+json">
#              {
# "@context": "http://schema.org",
# "@type": "BreadcrumbList",
# "itemListElement": [
# {
# "@type": "ListItem",
# "position": 1,
# "item": {
# "@id": "https://www.thebalancecareers.com/career-paths-4161858",
# "name": "Career Paths"
# }
# }
# ,
# {
# "@type": "ListItem",
# "position": 2,
# "item": {
# "@id": "https://www.thebalancecareers.com/advertising-4161818",
# "name": "Advertising"
# }
# }
# ,
# {
# "@type": "ListItem",
# "position": 3,
# "item": {
# "@id": "https://www.thebalancecareers.com/advertising-glossary-4161817",
# "name": "Basics"
# }
# }
# ]
# }
#             </script>
#             <link data-glb-css="" href="/static/3.10.0/cache/eNqtVu2WnCAMfaFyfIj-7UtEjJizkVjAnbVPX0BnVy1-zJ7-mIQbbpgkhmjlAwTSlfa-Skv8Ua0sPZDdGKgHg2pg0NgJN-i-dqUfxKINvoIm_0pbPTYEFWmxfpYl0oMag1F3SKYLPzuwBn-RD2jRFY3FIFw0MD71DYqK8cTjQsXx2CyOM2jJjA4XdZbDOzUoqWBTjD1VcG14Jajs9z-8X3H7PdKfLEpOyyb6QAcPMjMc-pFDcd_COxlI7lXtEBrtxr72Kpr3-PhJBPgQK_2kUjtt0SuZtowfWdyPc72-81ddZMcmWEOyZo-_cZIf6_1hX6az5vSiCVj5DmIv5_tuQ4Qr623vK6d6DCFd-oEsBVUHe3W3lIYhV3wL75SnxwAbcNupnpgsLuq21zg0cXA2KskNOKue7mTIokQ63XyW8vOBJaKarWf8RR9N7HRcugBUx7wOxveTx7kBawHXHNEuKB51HhvxFePFukkthj0utslCyXN6DUrkZH_RRceYsyhWk0W_XXAMSw1cLdd0Vic8FiNZlDituD4y02su3S8Ep7sdvBhZ7cjstUO0ebJu4ZUv9MTT7Pe5PEmlFQkx5Vkdp2Px4RlD5ChPxo7Dv5ZiYN9zW390gHPyuEh6mWWtMMtji67KlfOOjWXf_Ab8BWkZoGM.min.css" rel="stylesheet" type="text/css"/>
#             <script data-glb-js="top" src="/static/3.10.0/cache/eNqVkFFOAzEMRC9ElDsgVfzSZS-QZK3F7CZebKdVe3oStQJXLB_8JW8840m8aFBM_kN8ZAjLRlhUnvwPPkGZiH2mCbjgla32DZ2CGFuivFGBluQjnYEboAVBXPPcj3_Pflbgiyhjmf2EohbY5VVxRbVRDb68jjvl9Z1JdQUrMTSxwsghLTb5d3cRByvkhlyv0jZ64eQHELzCGxQh_r_7cGPHG9rpnKooZddbqpW3GqVGS4bx2V61v2jQeOjOh-QcLhH2qoZJuj5vj5vCDO6EcN6zzJr7TFoxLU7vn_gFbgvgOA.min.js" type="text/javascript">
#             </script>
#             <script type="text/javascript">
#              var Money = window.Money || {};
# Money.rightrailBreakpoint = "med2";
# Money.dfpAccountId = "479";var Mntl = window.Mntl || {};
# Mntl.RTB = Mntl.RTB || {};
# Mntl.RTB.setTimeoutLength([700,500]);
# Mntl.RTB.initBidders([{ type: "indexUniversal", id: '183710-265406164898442'},{ type: "amazon", id: '3222'},{ type: "ias", id: '926268'},{ type: "lotame", id: '5047'}]);
# Mntl.RTBTracking.init(['indexUniversal','amazon','ias','lotame']);
# Mntl.RTB.setAmazonSection('Basics');
# Mntl.RTB.setAmazonSlotName(false);
# Mntl.RTB.setGDPR(false);
# (function(){
# var pageTargeting = {
# rec: 0
# ,tax0: 'balcar'
# ,rid: 'g164ad46efb33112f'
# ,sid: 'g164ad46efb33112f'
# }
# ;
# var baseSlotTargeting = {
# inf: '0'
# ,entryType: 'direct'
# ,leaid: '84966'
# ,amp: '0'
# ,docId: '39208'
# ,ptax: 'balcar_advertising'
# ,vid: '0'
# ,tax1: 'balcar_career-paths'
# ,tax2: 'balcar_advertising'
# ,chpg: '1'
# ,t: '65'
# ,au: '84966'
# ,tier: 'M'
# ,jny: '0'
# ,leuid: '151378030080892'
# ,sbj: ''
# ,aid: '3253894aa1002b2ae3006dec'
# ,tax3: 'balcar_advertising-glossary'
# ,tax4: ''
# }
# ;
# pageTargeting.w = Mntl.utilities.getW();
# Money.GPT.testIds(pageTargeting, baseSlotTargeting);
# Mntl.utilities.onLoad(function() {
# Mntl.utilities.loadExternalJS({
# src: '//www.googletagservices.com/tag/js/gpt.js',
# async: 'true',
# attr: {
# defer: true
# }
# });
# });
# Mntl.GPT.init({
# domain: 'www.thebalancecareers.com',
# isMobile: false,
# dfpId: '479',
# singleRequest: false,
# priorityThreshold: 500,
# pageTargeting: pageTargeting,
# baseSlotTargeting: baseSlotTargeting,
# initialSlots: [{
# config: {id: 'leaderboard', sizes: [[728, 90], [970, 250], [970, 90], [1, 1]], type: 'leaderboard', rtb: true},
# targeting: Mntl.utilities.deepExtend({}, {
# pos: 'atf',
# priority: 1
# })
# },{
# config: {id: 'billboard', sizes: [[300, 250], [300, 600], [160, 600], [300, 1050], [1, 2], 'fluid'], type: 'billboard', rtb: true},
# targeting: Mntl.utilities.deepExtend({}, {
# pos: 'atf',
# priority: 2
# })
# }],
# utils: {
# collapseAd: Money.GPT.collapseAd,
# generateSlotId: Money.GPT.generateSlotId,
# buildGptUrl: Money.GPT.buildGptUrl
# }
# });
# }());// moved from gtm.ftl so we can initialize GTM only onLoad. From https://support.google.com/tagmanager/answer/6103696?hl=en
# Mntl.utilities.onLoad(function() {
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;defer=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-PTMG3HT');
# });
# var dataLayer = dataLayer || [];
# dataLayer.push({
# abTests: [{
# testName: "IASdirectOnly",
# bucketDescription: "in Test",
# bucketName: "inTest",
# bucketTrackingId: "41",
# bucketValue: 1
# },{
# testName: "evenFinancial",
# bucketDescription: "in test, even financial widget displays",
# bucketName: "showEvenFinancial",
# bucketTrackingId: "99",
# bucketValue: 1
# },{
# testName: "journeysRecirc",
# bucketDescription: "in test, journeys recirc replaced with non-journeys (sciences) recirc",
# bucketName: "sciences",
# bucketTrackingId: "99",
# bucketValue: 1
# },{
# testName: "lazyAdOffsetMobile",
# bucketDescription: "custom offset",
# bucketName: "customOffset",
# bucketTrackingId: "99",
# bucketValue: 1
# },{
# testName: "lazyWidgets",
# bucketDescription: "In test, widgets lazy load",
# bucketName: "active",
# bucketTrackingId: "55",
# bucketValue: 1
# },{
# testName: "rtbLoadMetrics",
# bucketDescription: "in test, rtb load metrics reported to datalayer",
# bucketName: "enabled",
# bucketTrackingId: "78",
# bucketValue: 1
# },{
# testName: "trackGBR",
# bucketDescription: "in test, tracking subId appended to GBR iframe src",
# bucketName: "enabled",
# bucketTrackingId: "99",
# bucketValue: 1
# }
# ],
# envData: {
# environment: {
# environment: "prod",
# application: "money-careers",
# dataCenter: "us-east-1"
# },
# server: {
# version: "3.10.0",
# vendor: "",
# title: "money-careers-server"
# },
# client : {
# browserUA: navigator.userAgent,
# serverUA: "Python-urllib/3.6",
# deviceType: "pc",
# usStateCode: "FL"
# }
# }
# });
# (function(){
# var pageViewDataAsJSON = {"description":"Here is a list of the 100 best taglines from brands around the world; most are American brands, but you may spot a few from other countries in there.","fullUrl":"https://www.thebalancecareers.com/best-advertising-taglines-ever-39208" + location.hash,"experienceType":"single page","currentPageOrdinal":"","previousPageOrdinal":"","entryType":"direct","pageviewType":"standard","templateVariation":"","publishDate":"2014-05-31","updateDate":"2017-12-08","numOfImages":1,"numOfPages":1,"numOfArticleWords":"","numOfInlineLinks":"","excludeFromComscore":false,"socialImage":"https://www.thebalancecareers.com/thmb/LWOxtM02LT9m1bbB59JRSYulxbM=/735x0/GettyImages-200121272-002-5894d3485f9b5874ee1d84d0.jpg","numOfMapLabels":"","isErrorPage":false,"instartLogicDelivered":0,"internalSessionId":"g164ad46efb33112f","internalRequestId":"g164ad46efb33112f","taxonomyNodes":[[{"documentId":4161173,"shortName":"The Balance Careers"},{"documentId":4161858,"shortName":"Career Paths"},{"documentId":4161818,"shortName":"Advertising"},{"documentId":4161817,"shortName":"Basics"}]],"isCommerceDocument":false,"experienceTypeName":"","recircDocIdsFooter":"","euTrafficFlag":false,"geoIpCountry":"US","errorType":"","contentGroup":"Articles","authorId":"84966","title":"The 100 Best Advertising Taglines Ever" || document.title || '',"documentId":39208,"templateId":"65","fastlyCountry":"US","lastEditingAuthorId":"84966","lastEditingUserId":"151378030080892","characterCount":7905,"socialTitle":"Take a Look at This List of the 100 Best Advertising Taglines Ever"};
# pageViewDataAsJSON.breakpointName = Mntl.utilities.getW();
# Mntl.PageView.init(pageViewDataAsJSON);
# })();
#             </script>
#             <script type="application/ld+json">
#              {
# "@context": "http://schema.org",
# "@type": "Article",
# "mainEntityOfPage": {
# "@type": "Webpage",
# "@id": "https://www.thebalancecareers.com/best-advertising-taglines-ever-39208"
# },
# "headline": "Take a Look at This List of the 100 Best Advertising Taglines Ever"
# ,"image": [
# {
# "@type": "ImageObject",
# "url": "https://www.thebalancecareers.com/thmb/P80OuO9eR_j5w66O5tszWYZBcDM=/1922x1560/filters:no_upscale():fill(transparent,1)/GettyImages-200121272-002-5894d3485f9b5874ee1d84d0.jpg",
# "height": 1560,
# "width": 1922
# }
# ]
# ,"datePublished": "2014-05-31T03:21:07.000Z"
# ,"dateModified": "2017-12-08T22:02:35.652Z"
# ,"author": {
# "@type": "Person",
# "name": "Paul Suggett"
# }
# ,"publisher": {
# "@type": "Organization",
# "name": "The Balance Careers",
# "logo": {
# "@type": "ImageObject",
# "url": "https://www.thebalancecareers.com/thmb/0XGBs7QGU6UnRxPWo6EnDsBWaX4=/160x60/filters:no_upscale():max_bytes(150000):strip_icc()/money-careers-publisher-logo-5ac272f5ff1b780037981793.png",
# "width": 160,
# "height": 60
# }
# }
# ,"description": "Here is a list of the 100 best taglines from brands around the world; most are American brands, but you may spot a few from other countries in there."
# ,"articleBody": "&lt;p&gt;Think about the brands that you know well, and perhaps even love. Chances are, it&amp;#39;s not just a brand name you&amp;#39;re recalling, but a &lt;a href=&quot;https://www.thebalancecareers.com/how-to-write-a-great-tagline-for-your-company-38718&quot; data-component=&quot;link&quot; data-source=&quot;inlineLink&quot; data-type=&quot;internalLink&quot; data-ordinal=&quot;1&quot;&gt;tagline&lt;/a&gt;, too. Almost all brands, products, and large corporations have some kind of tagline. Some are timeless, others get replaced every decade, or even sooner if it’s just not resonating with the public.&lt;/p&gt;&lt;h3&gt;&lt;strong&gt;What Is a Tagline?&lt;/strong&gt;&lt;/h3&gt;&lt;p&gt;&lt;a href=&quot;https://www.thebalancecareers.com/when-taglines-get-lost-in-translation-39241&quot; data-component=&quot;link&quot; data-source=&quot;inlineLink&quot; data-type=&quot;internalLink&quot; data-ordinal=&quot;2&quot;&gt;Taglines&lt;/a&gt; (also called straplines, tags, slogans, or brand lines) can be inspirational, like a product philosophy, or they can be something fun and memorable. While some can impel you to be better, do more, or go further, others are simply a fun play on words. &lt;/p&gt;&lt;blockquote&gt;&lt;p&gt;A variant of a branding slogan, a tagline can be used in marketing materials and advertising. The idea behind the concept is to create&lt;strong&gt; a memorable dramatic phrase &lt;/strong&gt;that will sum up the tone and premise of an audio/visual product, or to &lt;strong&gt;reinforce and strengthen the audience&amp;#39;s memory &lt;/strong&gt;of a literary product.&lt;/p&gt;&lt;/blockquote&gt;&lt;p&gt;Over the years, thousands and thousands of taglines have come and gone, but some are legendary. Here, in no particular order (although Nike is clearly number one, and always will be), are 50 of the best taglines from brands around the world. Most are American brands, but you may spot a few from other countries in there. It&amp;#39;s also worth noting that the tagline from DeBeers was, and is, part of a strategy to artificially increase the value of diamonds. It has worked. &lt;/p&gt;&lt;h3&gt;&lt;strong&gt;How is a Tagline Created?&lt;/strong&gt;&lt;/h3&gt;&lt;p&gt;How taglines come into being varies greatly depending on the company, its history, its size, and the methodologies employed by the management. &lt;/p&gt;&lt;p&gt;In a small business, or one that is just starting out, it&amp;#39;s usually something generated by the owner or one of the employees. Passion projects are fairly easy to write for, especially if the founder is also the tagline creator. &lt;/p&gt;&lt;p&gt;In a larger company, or major corporation, several avenues could be explored. Most likely a professional branding agency (or agencies) will be called upon to work on the project. If it&amp;#39;s a branding pitch, agencies will compete against each other to create not only a tagline, but also a corporate identity package and perhaps some initial thoughts on advertising campaigns. &lt;/p&gt;&lt;p&gt;On the other hand, larger companies and corporations can still choose to keep things on a tight budget. The task may fall to an in-house creative department, an account management team, or a single copywriting professional will be hired on a freelance bases to produce ideas. &lt;/p&gt;&lt;p&gt;The tagline itself usually comes out of research about the company, things people have said about the product or service, attributes of the product or service, and feelings people have when they use it. As you can see from the many taglines below, they usually put a clever spin on something the product or service excels at. For example, &amp;#34;Central Heating For Kids&amp;#34; for the warm breakfast food Ready Brek, or &amp;#34;Finger Lickin&amp;#39; Good&amp;#34; for KFC&amp;#39;s fried chicken. The more memorable and unique a tagline is, the more it will help the brand to become famous. &lt;br/&gt; &lt;/p&gt;&lt;h3&gt;&lt;strong&gt;The TOP  ...
# "
# }
#             </script>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body class="loc body">
#   <!-- Google Tag Manager () -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PTMG3HT" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager -->
#   <svg class="is-hidden">
#    <defs>
#     <symbol id="icon-drawer-arrow">
#      <svg viewbox="0 0 32.42 19.04" xmlns="http://www.w3.org/2000/svg">
#       <g>
#        <path d="M16.21 19.04L0 2.83 2.83 0l13.38 13.38L29.59 0l2.83 2.83-16.21 16.21z">
#        </path>
#       </g>
#      </svg>
#     </symbol>
#     <symbol id="icon-magnifying-glass">
#      <svg viewbox="0 0 793.9 792" xmlns="http://www.w3.org/2000/svg">
#       <path d="M787.5 707.2L562 481.6c33.5-49 53.2-108.3 53.2-172.1C615.2 141.1 478.1 4 309.6 4S4 141.1 4 309.6s137.1 305.6 305.6 305.6c63.5 0 122.6-19.5 171.5-52.8L706.7 788l80.8-80.8zM118.3 309.6c0-105.5 85.8-191.3 191.3-191.3s191.3 85.8 191.3 191.3S415 500.8 309.6 500.8 118.3 415 118.3 309.6z">
#       </path>
#       <path d="M309.6 615.2C141.1 615.2 4 478.1 4 309.6S141.1 4 309.6 4s305.6 137.1 305.6 305.6-137.1 305.6-305.6 305.6zm0-496.9c-105.5 0-191.3 85.8-191.3 191.3s85.8 191.3 191.3 191.3S500.8 415 500.8 309.6 415 118.3 309.6 118.3z">
#       </path>
#       <path d="M439.954 521.248l80.821-80.822 266.719 266.718-80.822 80.822z">
#       </path>
# s39.8,90.8,88.9,90.8c51.3,0,85.4-36.9,85.4-88.8c0-6-0.6-10.1-1.4-15.1H89z" fill-rule="evenodd">
#       </path>
#       <polygon clip-rule="evenodd" fill-rule="evenodd" points="254,77.7 254,51.7 229,51.7 229,77.7 203,77.7 203,103.7
# 229,103.7 229,129.7 254,129.7 254,103.7 279,103.7 279,77.7 ">
#       </polygon>
#      </g>
#     </symbol>
#     <symbol id="icon-linkedin">
#      <svg data-name="Layer 1" viewbox="0 0 12.88 12.86" xmlns="http://www.w3.org/2000/svg">
#       <path d="M4.77,7.84H7.44v8.59H4.77V7.84ZM6.11,3.57A1.55,1.55,0,1,1,4.56,5.12,1.55,1.55,0,0,1,6.11,3.57" transform="translate(-4.56 -3.57)">
#       </path>
#       <path d="M9.12,7.84h2.56V9h0a2.8,2.8,0,0,1,2.53-1.39c2.7,0,3.2,1.78,3.2,4.09v4.71H14.77V12.25c0-1,0-2.28-1.39-2.28s-1.6,1.09-1.6,2.21v4.25H9.12V7.84Z" transform="translate(-4.56 -3.57)">
#       </path>
#      </svg>
#     </symbol>
#     <symbol id="icon-flipboard">
#      <svg data-name="Layer 1" viewbox="240.4 241 17.3 17.3" xmlns="http://www.w3.org/2000/svg">
#       <polygon fill="#ffffff" points="252,241 246.2,241 240.4,241 240.4,246.7 240.4,252.5 240.4,258.3 246.2,258.3 246.2,252.6
# 251.9,252.6 251.9,246.8 257.7,246.8 257.7,241">
#       </polygon>
#       <polygon fill="#f7e7e7" points="252,241 246.2,241 246.2,246.8 252,246.8 257.7,246.8 257.7,241">
#       </polygon>
#       <rect fill="#f7d1d1" height="5.8" width="5.8" x="246.2" y="246.8">
#       </rect>
#      </svg>
#     </symbol>
#     <symbol id="icon-flipboard--dark">
#      <svg data-name="Layer 1" viewbox="240.4 241 17.3 17.3" xmlns="http://www.w3.org/2000/svg">
#       <polygon fill="#222222" points="252,241 246.2,241 240.4,241 240.4,246.7 240.4,252.5 240.4,258.3 246.2,258.3 246.2,252.6
# 251.9,252.6 251.9,246.8 257.7,246.8 257.7,241">
#       </polygon>
#       <polygon fill="#2d3238" points="252,241 246.2,241 246.2,246.8 252,246.8 257.7,246.8 257.7,241">
#       </polygon>
#       <rect fill="#424e5a" height="5.8" width="5.8" x="246.2" y="246.8">
#       </rect>
#      </svg>
#     </symbol>
#     <symbol id="icon-envelope2" viewbox="0 0 12.99 9.15">
#      <polygon points="0 0 12.99 0 6.5 4.83 0 0">
#      </polygon>
#      <polygon points="0 2.01 6.5 6.83 12.99 2.01 12.99 9.15 0 9.15 0 2.01">
#      </polygon>
#     </symbol>
#     <symbol id="icon-hamburger" viewbox="0 0 23.96 19.49">
#      <rect class="cls-1" height="3.57" width="23.96">
#      </rect>
#      <rect class="cls-1" height="3.57" width="23.96" y="7.96">
#      </rect>
#      <rect class="cls-1" height="3.57" width="23.96" y="15.92">
#      </rect>
#     </symbol>
#     <symbol id="icon-x">
#      <svg data-name="Layer 1" viewbox="0 0 25.73 25.73" xmlns="http://www.w3.org/2000/svg">
#       <path d="M3.449.004l22.28 22.28-3.45 3.451L-.002 3.455z">
#       </path>
#       <path d="M25.726 3.449l-22.28 22.28-3.451-3.45L22.275-.002z">
#       </path>
#      </svg>
#     </symbol>
#     <symbol id="icon-triangle-right">
#      <svg viewbox="0 0 60 60" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       
#         </path>
#        </g>
#       </g>
#      </svg>
#     </symbol>
#     <symbol id="icon-news">
#      <svg viewbox="0 0 34 34" xmlns="http://www.w3.org/2000/svg">
#       <g data-name="Layer 2">
#        <g data-name="Layer 1">
#         <path d="M6.62 34a.7.7 0 0 1-.7-.7v-7.36H.7a.7.7 0 0 1-.7-.7V.7A.7.7 0 0 1 .7 0h32.6a.7.7 0 0 1 .7.7v24.54a.7.7 0 0 1-.7.7H16.51l-9.44 7.9a.7.7 0 0 1-.45.16zM1.4 24.54h5.22a.7.7 0 0 1 .7.7v6.56l8.49-7.09a.7.7 0 0 1 .45-.16H32.6V1.4H1.4z">
#         </path>
#         <path d="M26.79 8.95H7.21a.7.7 0 0 1 0-1.4h19.58a.7.7 0 0 1 0 1.4zM26.79 13.72H7.21a.7.7 0 1 1 0-1.4h19.58a.7.7 0 0 1 0 1.4zM17.58 18.49H7.21a.7.7 0 1 1 0-1.4h10.37a.7.7 0 1 1 0 1.4z">
#         </path>
#        </g>
#       </g>
#      </svg>
#     </symbol>
#     <symbol id="icon-no-results">
#      <svg viewbox="0 0 35.89 37.72" xmlns="http://www.w3.org/2000/svg">
#       <g data-name="Layer 2">
#        <g data-name="Layer 1" fill="#444">
#         <path d="M17.59 20a.7.7 0 0 1-.35-.09L4.71 12.62a.7.7 0 0 1 .7-1.21l11.93 6.89L21 11.91 9.1 5a.7.7 0 0 1 .7-1.21L22.33 11a.7.7 0 0 1 .26 1l-4.39 7.6a.7.7 0 0 1-.61.4z">
#         </path>
#         <path d="M29.86 25a.7.7 0 0 1-.35-.09l-11.4-6.58a.7.7 0 1 1 .7-1.21l10.79 6.25 2-3.38-10.83-6.23a.7.7 0 1 1 .7-1.21l11.4 6.58a.7.7 0 0 1 .26 1l-2.65 4.59A.7.7 0 0 1 30 25z">
#         </path>
#         <path d="M33.74 25.88a.7.7 0 0 1-.35-.09l-3.28-1.89a.7.7 0 0 1 .7-1.21l2.67 1.54.75-1.29-2.67-1.54a.7.7 0 1 1 .7-1.21l3.28 1.89a.7.7 0 0 1 .26 1l-1.45 2.51a.7.7 0 0 1-.61.29zM4 14.51a.7.7 0 0 1-.35-.09L.35 12.5a.7.7 0 0 1-.26-1L6.56.35a.7.7 0 0 1 1-.26L10.84 2a.7.7 0 0 1 .26 1L4.63 14.16a.7.7 0 0 1-.63.35zm-2.34-2.87l2.11 1.22 5.76-10-2.11-1.2zM18.91 23.07a2.53 2.53 0 1 1 2.53-2.53 2.53 2.53 0 0 1-2.53 2.53zm0-3.65A1.13 1.13 0 1 0 20 20.54a1.13 1.13 0 0 0-1.09-1.12z">
#         </path>
#         <path d="M18.91 37.72a.7.7 0 0 1-.7-.7V22.37a.7.7 0 0 1 1.4 0V37a.7.7 0 0 1-.7.72z">
#         </path>
#         <path d="M11.37 37.26a.7.7 0 0 1-.63-1l7-14.19a.7.7 0 1 1 1.26.62l-7 14.18a.7.7 0 0 1-.63.39z">
#         </path>
#         <path d="M463,24.48c-2.09-.35-3.81-.56-5.19-.74l-1.71-.22c-2.37-.34-3.38-1.29-3.38-3.19A3.77,3.77,0,0,1,455.29,17a6.84,6.84,0,0,1,3.12-.52,6.17,6.17,0,0,1,4.33,1.39A4.66,4.66,0,0,1,464.2,21l0,.52h5.85V21a8.69,8.69,0,0,0-2.15-5.81c-1.92-2.43-5.38-3.82-9.51-3.82a12.22,12.22,0,0,0-8.79,3.32,8.8,8.8,0,0,0-2.53,6c0,4.47,2.72,7.46,7.47,8.21l6.43.85c2.58.35,4,1.6,4,3.53a3.54,3.54,0,0,1-1.22,2.69,7.13,7.13,0,0,1-4.9,1.45,8.46,8.46,0,0,1-4.81-1.19,5,5,0,0,1-2.1-4l0-.52h-5.86v.54A9.83,9.83,0,0,0,449,39.11c2.29,2.24,5.53,3.37,9.63,3.37s7.54-1.17,9.7-3.38h0a8.63,8.63,0,0,0,2.41-6.19C470.75,28.64,467.64,25.25,463,24.48Z" fill="#ffa846">
#         </path>
#        </g>
#       </g>
#      </svg>
#     </symbol>
#    </defs>
#   </svg>
#   <header class="comp header mntl-block" data-tracking-container="true" id="header_1-0" role="banner">
#    <div class="comp header__inner mntl-block" id="header__inner_1-0">
#     <div class="comp header__logo-wrapper mntl-block" id="header__logo-wrapper_1-0">
#      <a class="comp logo mntl-block" href="/" id="logo_1-0" rel="home">
#       <svg class="icon logo__icon ">
#        <use xlink:href="#logo__icon" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#       <svg class="icon logo__text ">
#        <use xlink:href="#logo__text" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#       The Balance Careers
#       <div class="comp header__centered-logo mntl-block" id="header__centered-logo_1-0">
#        <svg class="icon logo__icon ">
#         <use xlink:href="#logo__icon" xmlns:xlink="http://www.w3.org/1999/xlink">
#         </use>
#        </svg>
#       </div>
#       <!-- end: comp header__centered-logo mntl-block -->
#      </a>
#      <!-- end: comp logo mntl-block -->
#     </div>
#     <!-- end: comp header__logo-wrapper mntl-block -->
#     <div class="comp header__heading-wrapper mntl-block" id="header__heading-wrapper_1-0">
#      <div class="comp header__heading mntl-text-block" id="header__heading_1-0">
#       The 100 Best Advertising Taglines Ever
#      </div>
#      <!-- end: comp header__heading mntl-text-block -->
#     </div>
#     <!-- end: comp header__heading-wrapper mntl-block -->
#     <div class="comp header__main-wrapper mntl-block" id="header__main-wrapper_1-0">
#      <button class="comp header__hamburger-button mntl-block" id="header__hamburger-button_1-0">
#       Menu
#       <svg class="icon icon-hamburger ">
#        <use xlink:href="#icon-hamburger" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#       <svg class="icon icon-x ">
#        <use xlink:href="#icon-x" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#      </button>
#      <!-- end: comp header__hamburger-button mntl-block -->
#      <button class="comp header__search-button mntl-block" id="header__search-button_1-0">
#       Search
#       <svg class="icon icon-magnifying-glass ">
#        <use xlink:href="#icon-magnifying-glass" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#      </button>
#      <!-- end: comp header__search-button mntl-block -->
#     </div>
#     <!-- end: comp header__main-wrapper mntl-block -->
#     <form action="/search" class="comp general-search" data-tracking-container="true" id="general-search_1-0" method="get" role="search">
#      <div class="input-group">
#       <svg class="icon-magnifying-glass">
#        <use xlink:href="#icon-magnifying-glass" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#       <input class="general-search__input" name="q" placeholder="Search" required="" type="text" value=""/>
#       <button class="general-search__button button button--medium button--moon" type="submit">
#        Go
#       </button>
#      </div>
#     </form>
#     <!-- end: comp general-search -->
#    </div>
#    <!-- end: comp header__inner mntl-block -->
#    <nav class="comp fullscreen-nav dark-background" data-tracking-container="true" id="fullscreen-nav_1-0" role="navigation">
#     <svg class="icon logo__text ">
#      <use xlink:href="#logo__text" xmlns:xlink="http://www.w3.org/1999/xlink">
#      </use>
#     </svg>
#     <form action="/search" class="comp general-search" data-tracking-container="true" id="general-search_2-0" method="get" role="search">
#      <div class="input-group">
#       <svg class="icon-magnifying-glass">
#        <use xlink:href="#icon-magnifying-glass" xmlns:xlink="http://www.w3.org/1999/xlink">
#        </use>
#       </svg>
#       <input class="general-search__input" name="q" placeholder="Enter your search..." required="" type="text" value=""/>
#       <button class="general-search__button button button--medium button--moon" type="submit">
#        Go
#       </button>
#      </div>
#     </form>
#     <!-- end: comp general-search -->
#     <ul class="fullscreen-nav__list">
#      <li class="fullscreen-nav__list-item">
#       <a class="fullscreen-nav__list-heading" href="https://www.thebalancecareers.com/finding-a-job-4161644">
#        Finding a Job
#       </a>
#       <!-- end: fullscreen-nav__list-heading -->
#       <ul class="fullscreen-nav__sublist">
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/job-search-4161939">
#          Job Searching
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/career-planning-4161894">
#          Career Planning
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/internships-4161879">
#          Internships
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/work-at-home-jobs-4161867">
#          Work-From-Home-Jobs
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-cta" href="https://www.thebalancecareers.com/finding-a-job-4161644">
#          View All
#          <svg class="icon icon-open-arrow">
#           <use xlink:href="#icon-open-arrow" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#         <!-- end: fullscreen-nav__sublist-cta -->
#        </li>
#       </ul>
#      </li>
#      <li class="fullscreen-nav__list-item">
#       <a class="fullscreen-nav__list-heading" href="https://www.thebalancecareers.com/career-paths-4161858">
#        Career Paths
#       </a>
#       <!-- end: fullscreen-nav__list-heading -->
#       <ul class="fullscreen-nav__sublist">
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/military-careers-4161856">
#          US Military Careers
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/sales-4161808">
#          Sales
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/entertainment-careers-4161780">
#          Entertainment Careers
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/tech-careers-4161774">
#          Technology Careers
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-cta" href="https://www.thebalancecareers.com/career-paths-4161858">
#          View All
#          <svg class="icon icon-open-arrow">
#           <use xlink:href="#icon-open-arrow" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#         <!-- end: fullscreen-nav__sublist-cta -->
#        </li>
#       </ul>
#      </li>
#      <li class="fullscreen-nav__list-item">
#       <a class="fullscreen-nav__list-heading" href="https://www.thebalancecareers.com/succeeding-at-work-4161688">
#        Succeeding at Work
#       </a>
#       <!-- end: fullscreen-nav__list-heading -->
#       <ul class="fullscreen-nav__sublist">
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/human-resources-4161680">
#          Human Resources
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/management-4161687">
#          Management &amp; Leadership
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/women-in-business-4161654">
#          Women in Business
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-link" href="https://www.thebalancecareers.com/work-family-balance-4161649">
#          Work-Family Balance
#         </a>
#         <!-- end: fullscreen-nav__sublist-link -->
#        </li>
#        <li class="fullscreen-nav__sublist-item">
#         <a class="fullscreen-nav__sublist-cta" href="https://www.thebalancecareers.com/succeeding-at-work-4161688">
#          View All
#          <svg class="icon icon-open-arrow">
#           <use xlink:href="#icon-open-arrow" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#         <!-- end: fullscreen-nav__sublist-cta -->
#        </li>
#       </ul>
#      </li>
#     </ul>
#     <div class="comp fullscreen-nav__triple-cluster mntl-block" id="fullscreen-nav__triple-cluster_1-0">
#     </div>
#     <!-- end: comp fullscreen-nav__triple-cluster mntl-block -->
#     <div class="comp family-nav mntl-block" id="family-nav_1-0">
#      <div class="comp family-nav__content mntl-block" id="family-nav__content_1-0">
#       <div class="comp family-nav__title mntl-text-block" id="family-nav__title_1-0">
#        visit our other sites
#       </div>
#       <!-- end: comp family-nav__title mntl-text-block -->
#       <a class="comp family-nav__item mntl-block family-nav__item--balance" href="https://www.thebalance.com" id="family-nav__item_1-0" rel="nofollow noopener" target="_blank">
#       </a>
#       <!-- end: comp family-nav__item mntl-block family-nav__item--balance -->
# ...
#      </ul>
#      <!-- end: comp masonry-list mntl-masonry-tax-card-list mntl-masonry-card-list mntl-masonry-list mntl-block masonry-list -->
#      <div class="comp leaderboardfooter2 leaderboard--lazy leaderboard mntl-flexible-leaderboard mntl-flexible-ad mntl-gpt-adunit has-right-label js-lazy-ad gpt leaderboard dynamic" id="leaderboardfooter2_1-0">
#       <div class="wrapper" data-pos="ft2" data-priority="7" data-rtb="true" data-sizes="[[728, 90], [728, 99], [970, 250], [970, 259], [1, 10]]" data-targeting="{}" data-type="leaderboard" id="leaderboardfooter2">
#       </div>
#      </div>
#      <!-- end: comp leaderboardfooter2 leaderboard--lazy leaderboard mntl-flexible-leaderboard mntl-flexible-ad mntl-gpt-adunit has-right-label js-lazy-ad gpt leaderboard dynamic -->
#     </div>
#     <!-- end: comp masonry-section-split mntl-block masonry-section masonry-section--16 -->
#    </div>
#    <!-- end: comp prefooter mntl-block -->
#   </main>
#   <footer class="comp footer mntl-block dark-background" data-tracking-container="true" id="footer_1-0" role="contentinfo">
#    <div class="comp footer__content mntl-block" id="footer__content_1-0">
#     <a class="comp logo-with-slogan logo mntl-block" href="/" id="logo-with-slogan_1-0" rel="home">
#      <svg class="icon logo__icon ">
#       <use xlink:href="#logo__icon" xmlns:xlink="http://www.w3.org/1999/xlink">
#       </use>
#      </svg>
#      <svg class="icon logo__text ">
#       <use xlink:href="#logo__text" xmlns:xlink="http://www.w3.org/1999/xlink">
#       </use>
#      </svg>
#      The Balance Careers
#     </a>
#     <!-- end: comp logo-with-slogan logo mntl-block -->
#     <div class="comp footer__below-wrapper mntl-block" id="footer__below-wrapper_1-0">
#      <div class="comp footer__below-wrapper-inner mntl-block" id="footer__below-wrapper-inner_1-0">
#       <div class="comp footer__people-image mntl-block" id="footer__people-image_1-0">
#       </div>
#       <!-- end: comp footer__people-image mntl-block -->
#       <form action="/newsletter/signup" class="comp newsletter-signup mntl-newsletter-signup" id="newsletter-signup_1-0" method="POST">
#        <div class="comp mntl-newsletter-signup__heading mntl-text-block" id="mntl-newsletter-signup__heading_1-0">
#         Our Best Money Tips, Delivered
#        </div>
#        <!-- end: comp mntl-newsletter-signup__heading mntl-text-block -->
#        <div class="comp mntl-newsletter-submit mntl-newsletter-submit__input-wrapper" id="mntl-newsletter-submit_1-0">
#         <input name="list[]" type="hidden" value=""/>
#         <input name="customEventName" type="hidden" value="IVonetap"/>
#         <input name="CSRFToken" type="hidden" value="ab9e61a218a53fb420d9f75c628da7c9"/>
#         <label class="mntl-newsletter-submit__label is-vishidden" for="mntl-newsletter-submit__input">
#          Email Address
#         </label>
#         <input class="mntl-newsletter-submit__input" id="mntl-newsletter-submit__input" name="email" pattern="\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,4}\b" placeholder="Enter your email..." required="" type="email"/>
#         <div class="comp newsletter-signup__submit-wrapper mntl-block" id="newsletter-signup__submit-wrapper_1-0">
#          <button class="comp newsletter-signup__submit-button button--medium button mntl-button" id="newsletter-signup__submit-button_1-0" type="submit">
#           Sign up
#          </button>
#          <!-- end: comp newsletter-signup__submit-button button--medium button mntl-button -->
#          <div class="comp newsletter-signup-submit__animated-arrow-wrapper mntl-block" id="newsletter-signup-submit__animated-arrow-wrapper_1-0">
#           <div class="comp arrow mntl-block is-animated" id="arrow_1-0">
#           </div>
#           <!-- end: comp arrow mntl-block is-animated -->
#          </div>
#          <!-- end: comp newsletter-signup-submit__animated-arrow-wrapper mntl-block -->
#         </div>
#         <!-- end: comp newsletter-signup__submit-wrapper mntl-block -->
#        </div>
#        <!-- end: comp mntl-newsletter-submit mntl-newsletter-submit__input-wrapper -->
#        <div class="comp mntl-newsletter-signup__success mntl-text-block" id="mntl-newsletter-signup__success_1-0">
#         You're in! Thanks for signing up.
#        </div>
#        <!-- end: comp mntl-newsletter-signup__success mntl-text-block -->
#        <div class="comp mntl-newsletter-signup__error mntl-text-block" id="mntl-newsletter-signup__error_1-0">
#         There was an error. Please try again.
#        </div>
#        <!-- end: comp mntl-newsletter-signup__error mntl-text-block -->
#       </form>
#       <!-- end: comp newsletter-signup mntl-newsletter-signup -->
#       <!--end mntl-newsletter-signup-->
#      </div>
#      <!-- end: comp footer__below-wrapper-inner mntl-block -->
#      <div class="comp footer__below-wrapper-inner mntl-block" id="footer__below-wrapper-inner_2-0">
#       <div class="comp social-follow mntl-block" id="social-follow_1-0">
#        <div class="comp social-follow__heading mntl-text-block" id="social-follow__heading_1-0">
#         Stay Connected
#        </div>
#        <!-- end: comp social-follow__heading mntl-text-block -->
#        <div class="comp social-follow__icons mntl-block" id="social-follow__icons_1-0">
#         <a class="comp social-follow__facebook mntl-block social-follow__icon" href="https://www.facebook.com/thebalancecom/" id="social-follow__facebook_1-0" rel="noopener" target="_blank">
#          <svg class="icon icon-facebook ">
#           <use xlink:href="#icon-facebook" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#         <!-- end: comp social-follow__facebook mntl-block social-follow__icon -->
#         <a class="comp social-follow__pinterest mntl-block social-follow__icon" href="https://www.pinterest.com/thebalance/" id="social-follow__pinterest_1-0" rel="noopener" target="_blank">
#          <svg class="icon icon-pinterest ">
#           <use xlink:href="#icon-pinterest" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#         <!-- end: comp social-follow__pinterest mntl-block social-follow__icon -->
#         <a class="comp social-follow__twitter mntl-block social-follow__icon" href="https://twitter.com/thebalance/" id="social-follow__twitter_1-0" rel="noopener" target="_blank">
#          <svg class="icon icon-twitter ">
#           <use xlink:href="#icon-twitter" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#         <!-- end: comp social-follow__twitter mntl-block social-follow__icon -->
#         <a class="comp social-follow__flipboard mntl-block social-follow__icon" href="https://flipboard.com/@thebalance?utm_source=thebalance&amp;utm_medium=follow&amp;utm_campaign=tools" id="social-follow__flipboard_1-0" rel="noopener" target="_blank">
#          <svg class="icon icon-flipboard--dark ">
#           <use xlink:href="#icon-flipboard--dark" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#         <!-- end: comp social-follow__flipboard mntl-block social-follow__icon -->
#         <a class="comp social-follow__linkedin mntl-block social-follow__icon" href="https://www.linkedin.com/company-beta/10909374/" id="social-follow__linkedin_1-0" rel="noopener" target="_blank">
#          <svg class="icon icon-linkedin ">
#           <use xlink:href="#icon-linkedin" xmlns:xlink="http://www.w3.org/1999/xlink">
#           </use>
#          </svg>
#         </a>
#         <!-- end: comp social-follow__linkedin mntl-block social-follow__icon -->
#        </div>
#        <!-- end: comp social-follow__icons mntl-block -->
#       </div>
#       <!-- end: comp social-follow mntl-block -->
#       <div class="comp footer-links" id="footer-links_1-0">
#        <nav class="footer-links__list footer-links__list--taxonomy" role="navigation">
#         <ul>
#          <li class="footer-links__item">
#           <a class="footer-links__link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="Finding_a_Job" href="https://www.thebalancecareers.com/finding-a-job-4161644">
#            Finding a Job
#           </a>
#           <!-- end: footer-links__link -->
#          </li>
#          <li class="footer-links__item">
#           <a class="footer-links__link" data-component="footerLinks" data-ordinal="2" data-source="footerLinks" data-type="Career_Paths" href="https://www.thebalancecareers.com/career-paths-4161858">
#            Career Paths
#           </a>
#           <!-- end: footer-links__link -->
#          </li>
#          <li class="footer-links__item">
#           <a class="footer-links__link" data-component="footerLinks" data-ordinal="3" data-source="footerLinks" data-type="Succeeding_at_Work" href="https://www.thebalancecareers.com/succeeding-at-work-4161688">
#            Succeeding at Work
#           </a>
#           <!-- end: footer-links__link -->
#          </li>
#         </ul>
#        </nav>
#        <ul class="footer-links__list footer-links__list--misc">
#         <li class="footer-links__item">
#          <a class="footer-links__link" data-component="footerLinks" data-ordinal="1" data-source="footerLinks" data-type="ourStory" href="https://www.thebalancecareers.com/about-us">
#           About Us
#          </a>
#          <!-- end: footer-links__link -->
#         </li>
#         <li class="footer-links__item">
#          <a class="footer-links__link" data-component="footerLinks" data-ordinal="2" data-source="footerLinks" data-type="advertiseWithUs" href="https://www.dotdash.com/our-brands/">
#           Advertise
#          </a>
#         </li>
#         <li class="footer-links__item">
#          <a class="footer-links__link" data-component="footerLinks" data-ordinal="3" data-source="footerLinks" data-type="termsOfUse" href="https://www.thebalancecareers.com/legal#terms">
#           Terms of Use
#          </a>
#          <!-- end: footer-links__link -->
#         </li>
#         <li class="footer-links__item">
#          <a class="footer-links__link" data-component="footerLinks" data-ordinal="4" data-source="footerLinks" data-type="privacyPolicy" href="https://www.thebalancecareers.com/legal#privacy">
#           Privacy Policy
#          </a>
#          <!-- end: footer-links__link -->
#         </li>
#         <li class="footer-links__item">
#          <a class="footer-links__link" data-component="footerLinks" data-ordinal="5" data-source="footerLinks" data-type="cookiePolicy" href="/legal#cookies">
#           Cookie Policy
#          </a>
#          <!-- end: footer-links__link -->
#         </li>
#         <li class="footer-links__item">
#          <a class="footer-links__link" data-component="footerLinks" data-ordinal="6" data-source="footerLinks" data-type="careersAtDotDash" href="http://jobs.jobvite.com/dotdash" rel="noopener nofollow" target="_blank">
#           Careers
#          </a>
#          <!-- end: footer-links__link -->
#         </li>
#         <li class="footer-links__item">
#          <a class="footer-links__link" data-component="footerLinks" data-ordinal="7" data-source="footerLinks" data-type="contact" href="https://www.thebalancecareers.com/about-us#ContactUs">
#           Contact
#          </a>
#          <!-- end: footer-links__link -->
#         </li>
#        </ul>
#       </div>
#       <!-- end: comp footer-links -->
#      </div>
#      <!-- end: comp footer__below-wrapper-inner mntl-block -->
#     </div>
#     <!-- end: comp footer__below-wrapper mntl-block -->
#    </div>
#    <!-- end: comp footer__content mntl-block -->
#   </footer>
#   <!-- end: comp footer mntl-block dark-background -->
#   <script async="" data-glb-js="bottom" defer="true" src="/static/3.10.0/cache/eNqNVFFWhDAMvJCVM6i__nmCQAPEDSk2QWRPb1hW5bmV5w9tJzPThDat1MCoqV614gQxIOOAYuFtwkyod9U13qRhTOIRreo0Y65eV8ZyHb5pbjMZMZlrQz0RW5jJ-vCLduPGcF6Uzqg_s73nIMYvTU7MJQsSwyzAVcR2zUy3Scb494YjNTZlbIldRmp7oKSCAc5JArROIDAMBl23bfZHqOSCH1umXl9gkpOu-htwX_k7Sky5sj4nM8aS6UyxQx97pK63px6kw2cvCcXzK4FHJu8UMYWRYdmK26-PdE2fxsunRDoMbuehjp6WcCK7Xqn7H6R4HlG3O9ucHv3I6gQ56gERsuOMD2XSVxWaGgIO2kPGVbVf_1tXFLnZSEL2aFI43v_V6p0RIB4wWsYPqhmPWYwQMV_-WCGVIXlQ6JwPWn_yfFvCGJrE0yBuSfUtWjIYQJPkxe-5t9x-USJ3nGrv6v6S73U4qGt9HmCG4isjOCujeaMFpU6m8Rb5BK408FQ.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    Mntl.utilities.scriptsOnLoad(document.querySelectorAll('script[data-glb-js="bottom"]'), function() {$.ajaxPrefilter(function (options, originalOptions, jqXHR) {
# if(options.type.toUpperCase() == 'POST') {
# if(options.contentType.indexOf("application/x-www-form-urlencoded") > -1) {
# if (typeof originalOptions.data === 'string') {
# if (originalOptions.data.length) {
# originalOptions.data += "&";
# }
# originalOptions.data += "CSRFToken=ab9e61a218a53fb420d9f75c628da7c9";
# options.data = originalOptions.data;
# }
# else {
# options.data = $.param(($.extend(originalOptions.data, { "CSRFToken": "ab9e61a218a53fb420d9f75c628da7c9" })), true);
# }
# }
# if (options.contentType.indexOf("application/json") > -1) {
# if (typeof originalOptions.data === 'string') {
# originalOptions.data = JSON.parse(originalOptions.data);
# }
# options.data = JSON.stringify($.extend(originalOptions.data, { "CSRFToken": "ab9e61a218a53fb420d9f75c628da7c9" }));
# }
# }
# });window.Mntl.amazonAffiliateTagger.init("aboutcom02thebalance-20", "39,208", true);window.Mntl.externalizeLinks.addPlugin(Mntl.amazonAffiliateTagger);
# window.Mntl.externalizeLinks.init();(function() {
# var article = document.getElementById('article_1-0');
# if (article && !article.gtmPageView) {
# article.gtmPageView = {"description":"Here is a list of the 100 best taglines from brands around the world; most are American brands, but you may spot a few from other countries in there.","fullUrl":"https://www.thebalancecareers.com/best-advertising-taglines-ever-39208" + location.hash,"experienceType":"single page","currentPageOrdinal":"","previousPageOrdinal":"","entryType":"direct","pageviewType":"standard","templateVariation":"","publishDate":"2014-05-31","updateDate":"2017-12-08","numOfImages":1,"numOfPages":1,"numOfArticleWords":"","numOfInlineLinks":"","excludeFromComscore":false,"socialImage":"https://www.thebalancecareers.com/thmb/LWOxtM02LT9m1bbB59JRSYulxbM=/735x0/GettyImages-200121272-002-5894d3485f9b5874ee1d84d0.jpg","numOfMapLabels":"","isErrorPage":false,"instartLogicDelivered":0,"internalSessionId":"g164ad46efb33112f","internalRequestId":"g164ad46efb33112f","taxonomyNodes":[[{"documentId":4161173,"shortName":"The Balance Careers"},{"documentId":4161858,"shortName":"Career Paths"},{"documentId":4161818,"shortName":"Advertising"},{"documentId":4161817,"shortName":"Basics"}]],"isCommerceDocument":false,"experienceTypeName":"","recircDocIdsFooter":"","euTrafficFlag":false,"geoIpCountry":"US","errorType":"","contentGroup":"Articles","authorId":"84966","title":"The 100 Best Advertising Taglines Ever" || document.title || '',"documentId":39208,"templateId":"65","fastlyCountry":"US","lastEditingAuthorId":"84966","lastEditingUserId":"151378030080892","characterCount":7905,"socialTitle":"Take a Look at This List of the 100 Best Advertising Taglines Ever"};
# }
# }());
# (function() {
# Mntl.utilities.readyAndDeferred(function($container){
# var $masonryInstance = $('#masonry-list_1-0');
# if ($masonryInstance.data('no-js')) return;
# Mntl.MasonryList.init($container, $masonryInstance, {stretch: '.card__img'});
# });
# })();(function() {
# Mntl.utilities.readyAndDeferred(function($container){
# var $masonryInstance = $('#masonry-list_2-0');
# if ($masonryInstance.data('no-js')) return;
# Mntl.MasonryList.init($container, $masonryInstance, {stretch: '.card__img'});
# });
# })();Mntl.utilities.onLoad(function() {
# Mntl.utilities.loadExternalJS({
# src: '//s.skimresources.com/js/68756X1578615.skimlinks.js',
# async: true
# });
# });});
#   </script>
#   <svg class="is-hidden">
#    <defs>
#     <symbol id="mntl-sc-block-starrating-icon">
#      <svg viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg">
#       <path d="M0,0v20h20V0H0z M14.2,12.2l1.1,6.3l-5.4-3.2l-5.1,3.2l1-6.3L1.4,8l5.9-0.8l2.6-5.8l2.7,5.8L18.5,8L14.2,12.2z">
#       </path>
#      </svg>
#     </symbol>
#    </defs>
#   </svg>
#  </body>
# </html>
# <!-- end: comp flexTemplate html mntl-layout-html taxlevel-3 theme-1 -->

# %% [markdown]
# Great! Now lets target the text we want and start pulling it into a list called **slogans**:

# %%
unparsed_slogans = soup.find_all('strong')

slogans = []

for slogan in unparsed_slogans:
    slogans.append(slogan.get_text())

slogans[:10]
# Out:
# ['What Is a Tagline?',
#  ' a memorable dramatic phrase ',
#  "reinforce and strengthen the audience's memory ",
#  'How is a Tagline Created?',
#  'The TOP 100 Advertising Taglines Ever',
#  'A DIAMOND IS FOREVER – DeBeers, 1948',
#  'A LITTLE',
#  'DAB’LL',
#  'DO YA – Brylcreem,',
#  '1950s']

# %% [markdown]
# Okay, lets now get rid of all company names. Luckily, all names start after the '–' character in each slogan line, so we can slice it from there

# %%
parsed_slogans = []

for slogan in slogans:
    parsed_slogans.append(slogan.split('–')[0])

parsed_slogans[:10]
# Out:
# ['What Is a Tagline?',
#  ' a memorable dramatic phrase ',
#  "reinforce and strengthen the audience's memory ",
#  'How is a Tagline Created?',
#  'The TOP 100 Advertising Taglines Ever',
#  'A DIAMOND IS FOREVER ',
#  'A LITTLE',
#  'DAB’LL',
#  'DO YA ',
#  '1950s']

# %% [markdown]
# For the final part, lets put it into a CSV file

# %%
import csv

slogans = parsed_slogans

with open('./Data/slogans.csv', 'a') as csv_file:
    writer = csv.writer(csv_file)
    for slogan in slogans:
        writer.writerow([slogan])
